# %%
import pandas as pd
df=pd.read_csv("refined_diabetes_dataset.csv")

# %%
df.head()
# Out:
#    Diabetes_012  HighBP  HighChol       BMI  Smoker  Stroke  \
# 0             0       1         1  1.757936       1       0
# 1             0       0         0 -0.511806       1       0
# 2             0       1         1 -0.057858       0       0
# 3             0       1         0 -0.209174       0       0
# 4             0       1         1 -0.663122       0       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  ...  AnyHealthcare  \
# 0                     0             0       0        1  ...              1
# 1                     0             1       0        0  ...              0
# 2                     0             0       1        0  ...              1
# 3                     0             1       1        1  ...              1
# 4                     0             1       1        1  ...              1
#
#    GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  CardioIssue  \
# 0        5        18        15         1    0    9            0
# 1        3         0         0         0    0    7            0
# 2        5        30        30         1    0    9            0
# 3        2         0         0         0    0   11            0
# 4        2         3         0         0    0   11            0
#
#    HealthyLifestyleScore  ComorbidityCount
# 0                      2                 2
# 1                      2                 0
# 2                      2                 2
# 3                      4                 1
# 4                      4                 2
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Diabetes_012', 'HighBP', 'HighChol', 'BMI', 'Smoker', 'Stroke',
#        'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies',
#        'HvyAlcoholConsump', 'AnyHealthcare', 'GenHlth', 'MentHlth', 'PhysHlth',
#        'DiffWalk', 'Sex', 'Age', 'CardioIssue', 'HealthyLifestyleScore',
#        'ComorbidityCount'],
#       dtype='object')

# %%
import pandas as pd
import joblib

# Load model
model_path = "catboost_model.pkl"
loaded_model = joblib.load(model_path)

# Prepare new samples as DataFrame (only features, no target)
new_samples = pd.DataFrame([
    [1, 0, 28.5, 0, 0, 0, 1, 1, 0, 0, 1, 3, 1, 0, 0, 35, 0, 4, 2, 1],
    [0, 1, 32.0, 1, 0, 0, 0, 0, 0, 0, 4, 0, 1, 0, 1, 50, 0, 3, 3, 0]
], columns=['HighBP', 'HighChol', 'BMI', 'Smoker',
            'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies',
            'HvyAlcoholConsump', 'AnyHealthcare', 'GenHlth', 'MentHlth', 'PhysHlth',
            'DiffWalk', 'Sex', 'Age', 'CardioIssue', 'HealthyLifestyleScore', 'ComorbidityCount'])

# Predict
new_pred = loaded_model.predict(new_samples)
new_pred_proba = loaded_model.predict_proba(new_samples)

# Add predictions to DataFrame
new_samples['Predicted_Class'] = new_pred
new_samples['Prob_Class_0'] = new_pred_proba[:, 0]
new_samples['Prob_Class_1'] = new_pred_proba[:, 1]
new_samples['Prob_Class_2'] = new_pred_proba[:, 2]

new_samples
# Out:
#    HighBP  HighChol   BMI  Smoker  Stroke  HeartDiseaseorAttack  PhysActivity  \
# 0       1         0  28.5       0       0                     0             1
# 1       0         1  32.0       1       0                     0             0
#
#    Fruits  Veggies  HvyAlcoholConsump  ...  DiffWalk  Sex  Age  CardioIssue  \
# 0       1        0                  0  ...         0   35    0            4
# 1       0        0                  0  ...         1   50    0            3
#
#    HealthyLifestyleScore  ComorbidityCount  Predicted_Class  Prob_Class_0  \
# 0                      2                 1                0      0.950574
# 1                      3                 0                0      0.986424
#
#    Prob_Class_1  Prob_Class_2
# 0      0.001566      0.047860
# 1      0.002942      0.010634
#
# [2 rows x 24 columns]

# %%
import pandas as pd
import joblib

# Load model
model_path = "catboost_model.pkl"
loaded_model = joblib.load(model_path)

# Take first 5 or 10 rows from X_test
num_samples = 5  # or 10
new_samples = X_test.iloc[:num_samples].copy()  # ensures it's a DataFrame

# Predict
new_pred = loaded_model.predict(new_samples)
new_pred_proba = loaded_model.predict_proba(new_samples)

# Add predictions to DataFrame
new_samples['Predicted_Class'] = new_pred
new_samples['Prob_Class_0'] = new_pred_proba[:, 0]
new_samples['Prob_Class_1'] = new_pred_proba[:, 1]
new_samples['Prob_Class_2'] = new_pred_proba[:, 2]

print(new_samples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 10
#       8 # Take first 5 or 10 rows from X_test
#       9 num_samples = 5  # or 10
# ---> 10 new_samples = X_test.iloc[:num_samples].copy()  # ensures it's a DataFrame
#      12 # Predict
#      13 new_pred = loaded_model.predict(new_samples)
#
# NameError: name 'X_test' is not defined

# %%
from diagrams import Diagram, User, Container, Compute, Database

with Diagram("Diabetes Predictor Pipeline", show=False):
    user = User("User")
    ui = Container("Streamlit UI")
    api = Compute("FastAPI Service")
    model = Database("CatBoost Model")
    output = Container("Prediction Output")

    user >> ui >> api >> model >> output
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from diagrams import Diagram, User, Container, Compute, Database
#       3 with Diagram("Diabetes Predictor Pipeline", show=False):
#       4     user = User("User")
#
# ImportError: cannot import name 'User' from 'diagrams' (c:\Users\sarua\miniconda3\Lib\site-packages\diagrams\__init__.py)

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement User (from versions: none)
# ERROR: No matching distribution found for User

# %%
pip install diagrams graphviz
# Out:
# Requirement already satisfied: diagrams in c:\users\sarua\miniconda3\lib\site-packages (0.25.1)
# Requirement already satisfied: graphviz in c:\users\sarua\miniconda3\lib\site-packages (0.20.3)
# Requirement already satisfied: jinja2<4.0,>=2.10 in c:\users\sarua\miniconda3\lib\site-packages (from diagrams) (3.1.6)
# Requirement already satisfied: pre-commit<5,>=4.0.1 in c:\users\sarua\miniconda3\lib\site-packages (from diagrams) (4.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sarua\miniconda3\lib\site-packages (from jinja2<4.0,>=2.10->diagrams) (3.0.2)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\sarua\miniconda3\lib\site-packages (from pre-commit<5,>=4.0.1->diagrams) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\sarua\miniconda3\lib\site-packages (from pre-commit<5,>=4.0.1->diagrams) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\sarua\miniconda3\lib\site-packages (from pre-commit<5,>=4.0.1->diagrams) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sarua\miniconda3\lib\site-packages (from pre-commit<5,>=4.0.1->diagrams) (6.0.2)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\sarua\miniconda3\lib\site-packages (from pre-commit<5,>=4.0.1->diagrams) (20.35.4)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\sarua\miniconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\sarua\miniconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\sarua\miniconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit<5,>=4.0.1->diagrams) (4.3.7)
# Note: you may need to restart the kernel to use updated packages.
